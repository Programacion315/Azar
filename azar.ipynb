# %% [markdown]
# <a href="https://colab.research.google.com/github/Programacion315/Azar/blob/main/azar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Metodo de "Azar"
#
# ![azarDos.png](data:image/png;base64,...)

# %%
import numpy as np
import random as rd

# definir las variables
g = 9.8 #m/s^2
m = 100 #Kg
t = 198 #s
vtabla = 241 #Km/a

v = 241/3.6 #m/s

a = 14
b = 15
iteracion = 20
ea = 10

# definir la funcion p(c)
def p(c):
  funcion_vel = (g*m/c)*(1-np.exp(-c*t/m))-v
  return(funcion_vel)

# iteracion del metodo de la biseccion
a = 14
b = 15
iteracion = 20
ea = 100
c = 0
for i in range(0,iteracion):
  #c = (a+b)/2
  c = rd.uniform(a,b); #genera numeros aleatorios entre a y b decimales
  print(c)
  fb = p(b)
  fc = p(c)
  if i > 0:
    ea = abs(c-c_ant)*100/c
  c_ant = c # Guarda  el valor de c para calcular ea

  if fc == 0:
    print('valor real es:', c)
    break
  elif fc*fb<0:
    a = c
  else:
    b = c

print(c, ea)

#Generamos un numero entrea a y b que lleve decimales
#esto lo realizamos con la funcion uniform de la libreria random
#la cual genera numeros aleatorios decimales en el rango deseado

#Se genera un numero aletorio entre a y b hasta llegar a nuestro margen de error.
# Out:
# 14.649213640597642
# 14.176743257397533
# 14.600786007811001
# 14.645134416926785
# 14.640791898186533
# 14.613016115132238
# 14.615426729810903
# 14.63199559052041
# 14.637719791602422
# 14.639540832835301
# 14.638427215143752
# 14.639408576231551
# 14.639366700885542
# 14.638670116836408
# 14.639016298599325
# 14.638854034425973
# 14.63890484706384
# 14.638993915538366
# 14.639003781221835
# 14.639014885809726
# 14.639014885809726 7.585611448323517e-05
